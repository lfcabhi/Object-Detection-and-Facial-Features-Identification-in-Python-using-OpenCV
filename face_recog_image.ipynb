# %%
import cv2

# Load the cascade
face_cascade = cv2.CascadeClassifier('haar_cascade_files/haarcascade_frontalface_default.xml')
# Read the input image
img = cv2.imread('C:/Users/Abhishek/Documents/DL code/Jupyter_Notebooks/FINAL/lfc2.jpeg',1)

# %%
from IPython.display import Image
Image('C:/Users/Abhishek/Documents/DL code/Jupyter_Notebooks/FINAL/lfc2.jpeg')

# %%
# Convert into grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
gray
# Out:
# array([[204, 204, 204, ..., 163, 164, 164],
#        [204, 204, 204, ..., 163, 164, 164],
#        [204, 204, 204, ..., 162, 161, 161],
#        ...,
#        [152, 159, 170, ..., 159, 146, 146],
#        [138, 134, 137, ..., 160, 153, 154],
#        [129, 119, 116, ..., 159, 147, 149]], dtype=uint8)

# %%
# Detect faces
faces = face_cascade.detectMultiScale(gray, 1.2,3)
# Draw rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (25, 255, 25), 2)
cv2.imshow('img', img)
cv2.waitKey()

# %%
# Display the output
cv2.imshow('img', img)
cv2.waitKey()
